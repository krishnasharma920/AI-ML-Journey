# %%
text.upper()
# Out:
# ' PYTHON IS A VERY EASY LANGUAGE '

# %%
text.lower()
# Out:
# ' python is a very easy language '

# %%
text.title()
# Out:
# ' Python Is A Very Easy Language '

# %%
new_text = text.replace("easy","hard")
print(new_text)
# Out:
#  Python is a very hard language

# %%
text[0:5]
# Out:
# ' Pyth'

# %%
text[-6:]
# Out:
# 'guage '

# %%
device = ["keyboard","mouse","cpu","speaker","Ram"]

# %%
print(device)
# Out:
# ['keyboard', 'mouse', 'cpu', 'speaker', 'Ram']

# %%
device.append("usb")

# %%
print(device)
# Out:
# ['keyboard', 'mouse', 'cpu', 'speaker', 'Ram', 'usb']

# %%
device.remove("usb")
print(device)
# Out:
# ['keyboard', 'mouse', 'cpu', 'speaker', 'Ram']

# %%
    print(device[1])
print(device[3])
# Out:
# mouse
# speaker

# %%
device.reverse()
device[::-1]
# Out:
# ['keyboard', 'mouse', 'cpu', 'speaker', 'Ram']

# %%
movies = ( "gangs of vasepur", "RRR","x","y","z")
print(movies[2])
# Out:
# x

# %%
student ={
    "name" : "Krishna",
      "age" : "199",
"year" : 1,
"skills" : ["python", "jawa" , "css"]
}

# %%
student["name"]
# Out:
# 'Krishna'

# %%
student["new skills"] = "problem solving"

# %%
print(student)
# Out:
# {'name': 'Krishna', 'age': '199', 'year': 1, 'skills': ['python', 'jawa', 'css'], 'new skills': 'problem solving'}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'year', 'skills', 'new skills'])

# %%
student.values()
# Out:
# dict_values(['Krishna', '199', 1, ['python', 'jawa', 'css'], 'problem solving'])
